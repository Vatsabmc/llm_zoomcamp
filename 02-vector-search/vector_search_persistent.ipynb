# %%
# Reopen the index without re-computing the embeddings
from sentence_transformers import SentenceTransformer
from sqlitesearch import VectorSearchIndex

model = SentenceTransformer("all-MiniLM-L6-v2")

vs_index = VectorSearchIndex(
    keyword_fields=["course"],
    mode="ivf",
    db_path="faq_vectors2.db"
)
# Out:
# ...
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]

# %%
# Search only: no fit beacuse the index is already built
query_vector = model.encode("How do I run Kafka?")
results = vs_index.search(query_vector, num_results=5)

# %% [markdown]
# Using sqlitesearch vector search in RAG

# %%
# Set up the OenAI client and RAGVector class
from rag_helper import RAGBase
from dotenv import load_dotenv
from openai import OpenAI

load_dotenv()
openai_client = OpenAI()

class RAGVector(RAGBase):

    def __init__(self, embedder, **kwargs):
        super().__init__(**kwargs)
        self.embedder = embedder

    def search(self, query, num_results=5):
        query_vector = self.embedder.encode(query)
        filter_dict = {"course": self.course}

        return self.index.search(
            query_vector,
            num_results=num_results,
            filter_dict=filter_dict
        )

# Create the assistant with the vector search index and the OpenAI client
vector_assistant = RAGVector(
    embedder=model,
    index=vs_index,
    llm_client=openai_client,
)

# %%
vector_assistant.rag("the program has already begun, can I still sign up?")
# Out:
# 'Yes, you can still join. If you want a certificate, make sure to submit your project while submissions are still being accepted.'

# %%
vs_index.close()
